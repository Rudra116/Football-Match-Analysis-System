# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudra116/Football-Match-Analysis-System/blob/main/First_two_Inferences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.8/978.8 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# First Inference

# %%
# # Load a pretrained YOLOv8s model
# model = YOLO("yolov8s.pt")

# # Run prediction on a video file, save results
# results = model.predict(
#     source="/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4",
#     save=True
# )
# # Show first result summary
# print(results[0])
# print("=================================")

# # Print individual bounding boxes
# for box in results[0].boxes:
#     print(box)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 124MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4: 384x640 25 persons, 1 sports ball, 608.0ms
# video 1/1 (frame 2/750) /content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4: 384x640 23 persons, 1 sports ball, 411.4ms
# ...

# %% [markdown]
# Issues:
#
# 1)People who are not playing are also being deteced  (People outside the field)
#
# 2)Sometimes Players are not being detected at all

# %%
import shutil

# %%
# shutil.move("/content/runs/detect/predict/08fd33_4.avi",
#             "/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Inferences ")
# Out:
# '/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Inferences /08fd33_4.avi'

# %% [markdown]
# Second Inference : After finetuning on Roboflow Dataset

# %%
# #we load the weights of the model trained on
# model = YOLO("/content/drive/MyDrive/Projects/Football Analysis System with YOLO/YoloV5_Related/best.pt")

# # Run prediction on a video file, save results
# results = model.predict(
#     source="/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4",
#     save=True
# )
# # Show first result summary
# print(results[0])
# print("=================================")

# # Print individual bounding boxes
# for box in results[0].boxes:
#     print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 1285.0ms
# video 1/1 (frame 2/750) /content/drive/MyDrive/Projects/Football Analysis System with YOLO/Sample Data/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 1329.0ms
# ...

# %%
# shutil.move("/content/runs/detect/predict2/08fd33_4.avi",
#             "/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Inferences ")
# Out:
# '/content/drive/MyDrive/Projects/Football Analysis System with YOLO/Inferences /08fd33_4.avi'

# %% [markdown]
# Issues:
#
# 1)Visuals
#
# 2)GoalKeeper is also being deteced as a player sometimes{perhaps due to small dataset of approx 630 images}
